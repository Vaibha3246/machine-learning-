# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
df=pd.read_csv('C:/Users/vaibh/Downloads/placement (2).csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
df.shape
# Out:
# (200, 3)

# %%
sns.scatterplot(x='cgpa',y='package',data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('cgpa')
plt.ylabel('package')
plt.show()

# %%
y_predict=lr.predict(x_test)

# %%
print('MAE',mean_absolute_error(y_test,y_predict))
# Out:
# MAE 0.2606898249919377

# %%
print('MSE',mean_squared_error(y_test,y_predict))
# Out:
# MSE 0.09995369482155111

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# RMSE 0.3161545426236212

# %%
print('r2_score',r2_score(y_test,y_predict))
# Out:
# MSE 0.7525945592908275

# %%
# adjusted r2 score

# %%
df['random_feature']=np.random.random(200)

# %%
df=df[['cgpa','random_feature','package']]

# %%
df
# Out:
#      cgpa  random_feature  package
# 0    6.89        0.839677     3.26
# 1    5.12        0.070449     1.98
# 2    7.82        0.079813     3.25
# 3    7.42        0.174757     3.67
# 4    6.94        0.342831     3.57
# ..    ...             ...      ...
# 195  6.93        0.768780     2.46
# 196  5.89        0.292212     2.57
# 197  7.21        0.381372     3.24
# 198  7.63        0.383930     3.96
# 199  6.22        0.740109     2.33
#
# [200 rows x 3 columns]

# %%
plt.scatter(df['random_feature'],df['package'])
plt.xlabel('random_feature')
plt.ylabel('Package(in lpa')
# Out:
# Text(0, 0.5, 'Package(in lpa')

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)

# %%
print('MSE',r2_score(y_test,y_predict))
# Out:
# MSE 0.7733313833409471

# %%
r2=r2_score(y_test,y_predict)

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.761079025683701

# %%
new_df2 = df.copy()

new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]

# %%
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 60   5.61  2.79     2.19
# 158  5.95  3.34     3.04
# 45   7.87  2.98     3.58
# 117  7.12  3.99     2.99
# 132  5.84  3.38     2.48

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)

# %%
r2_score(y_test,y_predict)
# Out:
# 0.7733313833409471

# %%
r2=r2_score(y_test,y_predict)

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.761079025683701
