# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('C:/Users/vaibh/Downloads/wine_data.csv')
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
df=pd.read_csv('C:/Users/vaibh/Downloads/wine_data.csv',usecols=[0,1,2])
df
# Out:
#      1  14.23  1.71
# 0    1  13.20  1.78
# 1    1  13.16  2.36
# 2    1  14.37  1.95
# 3    1  13.24  2.59
# 4    1  14.20  1.76
# ..  ..    ...   ...
# 172  3  13.71  5.65
# 173  3  13.40  3.91
# 174  3  13.27  4.28
# 175  3  13.17  2.59
# 176  3  14.13  4.10
#
# [177 rows x 3 columns]

# %%
df.columns=['Class label','Alchool','Malic Acid']
df
# Out:
#      Class label  Alchool  Malic Acid
# 0              1    13.20        1.78
# 1              1    13.16        2.36
# 2              1    14.37        1.95
# 3              1    13.24        2.59
# 4              1    14.20        1.76
# ..           ...      ...         ...
# 172            3    13.71        5.65
# 173            3    13.40        3.91
# 174            3    13.27        4.28
# 175            3    13.17        2.59
# 176            3    14.13        4.10
#
# [177 rows x 3 columns]

# %%
sns.kdeplot(df['Alchool'])
# Out:
# <Axes: xlabel='Alchool', ylabel='Density'>

# %%
sns.kdeplot(df['Malic Acid'])
# Out:
# <Axes: xlabel='Malic Acid', ylabel='Density'>

# %%
sns.scatterplot(x='Alchool',y='Malic Acid',data=df,hue=df['Class label'],palette={1:'red',2:'green',3:'pink'})
# Out:
# <Axes: xlabel='Alchool', ylabel='Malic Acid'>

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(df.drop('Class label', axis=1),df['Class label'],test_size=.3,random_state=0)
x_train
# Out:
#      Alchool  Malic Acid
# 22     12.85        1.60
# 108    11.61        1.35
# 174    13.27        4.28
# 144    13.16        3.57
# 71     13.49        1.66
# ..       ...         ...
# 103    12.51        1.73
# 67     13.34        0.94
# 117    12.77        3.43
# 47     14.10        2.02
# 172    13.71        5.65
#
# [123 rows x 2 columns]

# %%
x_test
# Out:
#      Alchool  Malic Acid
# 54     13.56        1.73
# 150    12.79        2.67
# 63     12.17        1.45
# 55     14.22        1.70
# 123    11.87        4.31
# 121    12.42        4.43
# 7      14.83        1.64
# 159    12.36        3.83
# 106    12.72        1.75
# 90     12.00        1.51
# 165    13.45        3.70
# 145    13.88        5.04
# 5      14.39        1.87
# 98     12.29        3.17
# 167    13.58        2.58
# 80     12.72        1.81
# 33     13.51        1.80
# 18     13.64        3.10
# 61     13.67        1.25
# 51     13.82        1.75
# 66     12.37        1.17
# 37     13.07        1.50
# 4      14.20        1.76
# 104    12.42        2.55
# 60     12.64        1.36
# 111    11.76        2.68
# 126    11.79        2.13
# 86     11.65        1.67
# 112    11.41        0.74
# 163    13.78        2.76
# 26     13.30        1.72
# 56     13.29        1.97
# 129    12.86        1.35
# 45     14.38        3.59
# 8      13.86        1.35
# 44     14.21        4.04
# ...

# %%
y_train
# Out:
# 22     1
# 108    2
# 174    3
# 144    3
# 71     2
#       ..
# 103    2
# 67     2
# 117    2
# 47     1
# 172    3
# Name: Class label, Length: 123, dtype: int64

# %%
y_test
# Out:
# 54     1
# 150    3
# 63     2
# 55     1
# 123    2
# 121    2
# 7      1
# 159    3
# 106    2
# 90     2
# 165    3
# 145    3
# 5      1
# 98     2
# 167    3
# 80     2
# 33     1
# 18     1
# 61     2
# 51     1
# 66     2
# 37     1
# 4      1
# 104    2
# 60     2
# 111    2
# 126    2
# 86     2
# 112    2
# 163    3
# 26     1
# 56     1
# 129    3
# 45     1
# 8      1
# 44     1
# 160    3
# 92     2
# 94     2
# 173    3
# 24     1
# 30     1
# 93     2
# 101    2
# 113    2
# 19     1
# 134    3
# 74     2
# 143    3
# 16     1
# 131    3
# 137    3
# 40     1
# 157    3
# Name: Class label, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler() 

# fit the scaler to train set data , it will learn to the  parameter values

scaler.fit(x_train)

# transform train and test set 

x_train_scaled=scaler.transform(x_train)

x_test_scaled=scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[0.48924731, 0.14460285],
#        [0.15591398, 0.09368635],
#        [0.60215054, 0.6904277 ],
#        [0.57258065, 0.54582485],
#        [0.66129032, 0.15682281],
#        [0.48924731, 0.48472505],
#        [0.66935484, 0.46435845],
#        [0.76344086, 0.20570265],
#        [0.21774194, 0.        ],
#        [0.32795699, 0.78004073],
#        [0.36021505, 0.03665988],
#        [0.26075269, 0.51731161],
#        [0.5188172 , 0.52138493],
#        [0.36021505, 0.04887984],
#        [0.89784946, 0.21588595],
#        [0.34946237, 0.04276986],
#        [0.20967742, 0.25050916],
#        [0.33870968, 0.10590631],
#        [0.54301075, 0.17922607],
#        [0.83064516, 0.12016293],
#        [0.1155914 , 0.58044807],
#        [0.25      , 0.0407332 ],
#        [0.46774194, 0.30549898],
#        [0.65860215, 0.15885947],
#        [0.40053763, 0.31364562],
#        [0.37634409, 0.13034623],
#        [0.37365591, 0.14663951],
#        [0.51075269, 0.3910387 ],
# ...

# %%
# this data convert into a numpy array using transform 
# so we convert into a dataframe

# %%
x_train_scaled=pd.DataFrame(x_train_scaled,columns=x_train.columns)
x_test_scaled=pd.DataFrame(x_test_scaled, columns=x_test.columns)

# %%
x_test_scaled
# Out:
#      Alchool  Malic Acid
# 0   0.680108    0.171079
# 1   0.473118    0.362525
# 2   0.306452    0.114053
# 3   0.857527    0.164969
# 4   0.225806    0.696538
# 5   0.373656    0.720978
# 6   1.021505    0.152749
# 7   0.357527    0.598778
# 8   0.454301    0.175153
# 9   0.260753    0.126273
# 10  0.650538    0.572301
# 11  0.766129    0.845214
# 12  0.903226    0.199593
# 13  0.338710    0.464358
# 14  0.685484    0.344196
# 15  0.454301    0.187373
# 16  0.666667    0.185336
# 17  0.701613    0.450102
# 18  0.709677    0.073320
# 19  0.750000    0.175153
# 20  0.360215    0.057026
# 21  0.548387    0.124236
# 22  0.852151    0.177189
# 23  0.373656    0.338086
# 24  0.432796    0.095723
# 25  0.196237    0.364562
# 26  0.204301    0.252546
# 27  0.166667    0.158859
# 28  0.102151   -0.030550
# 29  0.739247    0.380855
# 30  0.610215    0.169043
# 31  0.607527    0.219959
# 32  0.491935    0.093686
# 33  0.900538    0.549898
# 34  0.760753    0.093686
# 35  0.854839    0.641548
# ...

# %%
x_train_scaled.describe()
# Out:
#           Alchool  Malic Acid
# count  123.000000  123.000000
# mean     0.523079    0.293676
# std      0.209894    0.237984
# min      0.000000    0.000000
# 25%      0.360215    0.136456
# 50%      0.543011    0.191446
# 75%      0.697581    0.445010
# max      1.000000    1.000000

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#        Alchool  Malic Acid
# count    123.0       123.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.1
# 50%        0.5         0.2
# 75%        0.7         0.4
# max        1.0         1.0

# %%
x_test_scaled
# Out:
#      Alchool  Malic Acid
# 0   0.680108    0.171079
# 1   0.473118    0.362525
# 2   0.306452    0.114053
# 3   0.857527    0.164969
# 4   0.225806    0.696538
# 5   0.373656    0.720978
# 6   1.021505    0.152749
# 7   0.357527    0.598778
# 8   0.454301    0.175153
# 9   0.260753    0.126273
# 10  0.650538    0.572301
# 11  0.766129    0.845214
# 12  0.903226    0.199593
# 13  0.338710    0.464358
# 14  0.685484    0.344196
# 15  0.454301    0.187373
# 16  0.666667    0.185336
# 17  0.701613    0.450102
# 18  0.709677    0.073320
# 19  0.750000    0.175153
# 20  0.360215    0.057026
# 21  0.548387    0.124236
# 22  0.852151    0.177189
# 23  0.373656    0.338086
# 24  0.432796    0.095723
# 25  0.196237    0.364562
# 26  0.204301    0.252546
# 27  0.166667    0.158859
# 28  0.102151   -0.030550
# 29  0.739247    0.380855
# 30  0.610215    0.169043
# 31  0.607527    0.219959
# 32  0.491935    0.093686
# 33  0.900538    0.549898
# 34  0.760753    0.093686
# 35  0.854839    0.641548
# ...

# %%
x_test_scaled.describe()
# Out:
#          Alchool  Malic Acid
# count  54.000000   54.000000
# mean    0.538779    0.298974
# std     0.235359    0.205388
# min     0.102151   -0.030550
# 25%     0.353495    0.153768
# 50%     0.545699    0.210794
# 75%     0.713710    0.436354
# max     1.021505    0.845214

# %%
np.round(x_test_scaled.describe(),1)
# Out:
#        Alchool  Malic Acid
# count     54.0        54.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.1        -0.0
# 25%        0.4         0.2
# 50%        0.5         0.2
# 75%        0.7         0.4
# max        1.0         0.8

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2, figsize=(12,5))

ax1.set_title('before scaling')

ax1.scatter(x='Alchool',y='Malic Acid', data=x_train, c=y_train)

# after scaling  

ax2.set_title('after scaling')

ax2.scatter(x='Alchool',y='Malic Acid', data=x_train_scaled,c=y_train)

# %%
fig, (ax1,ax2)= plt.subplots(ncols=2, figsize=(12,5))

# before scaling 

# ax1.set_title('before scaling') 
sns.kdeplot(x_train['Alchool'], ax=ax1 ,color='black')

sns.kdeplot(x_train['Malic Acid'], ax=ax1 )


# after scaling 

ax2.set_title('after standard scaling ') 

sns.kdeplot(x_train_scaled['Alchool'],ax=ax2, color='red')
sns.kdeplot(x_train_scaled['Malic Acid'], ax=ax2,color='green' )

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Alcohol Distribution Before Scaling')
sns.kdeplot(x_train['Alchool'], ax=ax1)

# after scaling
ax2.set_title('Alcohol Distribution After Standard Scaling')
sns.kdeplot(x_train_scaled['Alchool'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Malic acid Distribution Before Scaling')
sns.kdeplot(x_train['Malic Acid'], ax=ax1)

# after scaling
ax2.set_title('Malic acid Distribution After Standard Scaling')
sns.kdeplot(x_train_scaled['Malic Acid'], ax=ax2)
plt.show()
