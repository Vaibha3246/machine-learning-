# %%
from sklearn.datasets import make_regression

# %%
import numpy as np

# %%
x,y=make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
x
# Out:
# array([[-0.71239066],
#        [ 0.45181234],
#        [-0.04450308],
#        [ 0.75376638]])

# %%
y
# Out:
# array([  7.21786552,  16.04609925, -27.83756166, 144.36688189])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
# let ols apply

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x)

# %%
lr.coef_
# Out:
# array([78.35063668])

# %%
lr.intercept_
# Out:
# 26.15963284313262

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red')

# %%
# lets apply gradient descent assuming slope is 78.35 
# lets assume the starting value of b is 0
y_pred = ((78.35 * x) + b).reshape(4)

# %%
y_pred
# Out:
# array([ 27.89524526, 119.11055037,  80.22423745, 142.7686494 ])

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='ols')

plt.plot(x,y_pred,color='blue',label='b = 0')

plt.legend()
plt.show()

# %%
m=78.35
b=0
loss_slope=-2* np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# -209.27763408209216

# %%
learning_rate=.1 
step_size=loss_slope*learning_rate

# %%
step_size
# Out:
# -20.927763408209216

# %%
# calcute the new interscept
b=b - step_size
b
# Out:
# 20.927763408209216

# %%
y_pred1=78.35*x + b

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='ols')
plt.plot(x,y_pred,color='blue',label='b=0')
plt.plot(x,y_pred1,color='green',label='b=20.92')
plt.legend()
plt.show()

# %%
# iteration 2 
loss_slope=-2* np.sum(y - 78.35*x.ravel()-b)

# %%
loss_slope
# Out:
# -41.85552681641843

# %%
step_size=loss_slope*learning_rate

# %%
step_size
# Out:
# -4.185552681641844

# %%
b=b-step_size

# %%
b
# Out:
# 25.11331608985106

# %%
y_predict2= (78.35 *x +b).reshape(4)

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='ols')
plt.plot(x,y_pred,color='blue',label='b=0')
plt.plot(x,y_pred1,color='green',label='b=20.92')
plt.plot(x,y_predict2,color='yellow',label='b = {}'.format(b))

plt.legend()
plt.show()

# %%
# iteration 3 
loss_slope=-2* np.sum(y - 78.35*x.ravel()-b)

# %%
loss_slope
# Out:
# -8.371105363283675

# %%
step_size=loss_slope*learning_rate

# %%
step_size
# Out:
# -0.8371105363283675

# %%
b=b - step_size

# %%
b
# Out:
# 25.95042662617943

# %%
y_pred4= 78.35*x +b

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='ols')
plt.plot(x,y_pred,color='blue',label='b=0')
plt.plot(x,y_pred1,color='green',label='b=20.92')
plt.plot(x,y_predict2,color='yellow',label='b = 25.11331608985106')
plt.plot(x,y_pred4,color='violet',label='b = {}'.format(b))

plt.legend()
plt.show()

# %%
loss_slope=-2* np.sum(y - 78.35*x.ravel()-b)

# %%
loss_slope
# Out:
# -1.674221072656735

# %%
step_size=loss_slope*learning_rate
step_size
# Out:
# -0.16742210726567353

# %%
b=b-step_size
b
# Out:
# 26.1178487334451

# %%
y_pred5=78.35*x+b

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='ols')
plt.plot(x,y_pred,color='blue',label='b=0')
plt.plot(x,y_pred1,color='green',label='b=20.92')
plt.plot(x,y_predict2,color='yellow',label='b = 25.11331608985106')
plt.plot(x,y_pred4,color='violet',label='b = {}'.format(b))
plt.plot(x,y_pred5,color='pink',label='b = {}'.format(b))

plt.legend()
plt.show()

# %%
b=-100
m=78.35
learning_rate=.1

epochs=10

for i in range(epochs):
    loss_slope=-2*np.sum(y-m*x.ravel()-b)
    
    b=b-loss_slope*learning_rate
    
    y_pred=m*x+b
    
    
    plt.plot(x,y_pred)
plt.scatter(x,y)
