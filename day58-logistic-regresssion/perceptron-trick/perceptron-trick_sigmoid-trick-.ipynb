# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=100, n_features = 2, n_informative  = 1, n_redundant= 0, n_classes = 2, n_clusters_per_class=1, class_sep =20, hypercube=False, random_state=41)

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.linear_model import LogsisticRegression
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 from sklearn.linear_model import LogsisticRegression
#
# ImportError: cannot import name 'LogsisticRegression' from 'sklearn.linear_model' (C:\Users\vaibh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\__init__.py)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter')

# %%
import numpy as np

# %%
def step(z):
    return 1 if  z>0  else 0

# %%
intercept,coef=perceptron(x,y)

# %%
intercept
# Out:
# 1.3000000000000003

# %%
coef
# Out:
# array([0.98628302, 0.45500818])

# %%
m=-(coef[0]/coef[1])
b=-(intercept/coef[1])

# %%
m
# Out:
# -2.167616010716917

# %%
b
# Out:
# -2.857091482810232

# %%
x_input=np.linspace(-3,3,100)
y_input=m* x_input+b

# %%
x_input
# Out:
# array([-3.        , -2.93939394, -2.87878788, -2.81818182, -2.75757576,
#        -2.6969697 , -2.63636364, -2.57575758, -2.51515152, -2.45454545,
#        -2.39393939, -2.33333333, -2.27272727, -2.21212121, -2.15151515,
#        -2.09090909, -2.03030303, -1.96969697, -1.90909091, -1.84848485,
#        -1.78787879, -1.72727273, -1.66666667, -1.60606061, -1.54545455,
#        -1.48484848, -1.42424242, -1.36363636, -1.3030303 , -1.24242424,
#        -1.18181818, -1.12121212, -1.06060606, -1.        , -0.93939394,
#        -0.87878788, -0.81818182, -0.75757576, -0.6969697 , -0.63636364,
#        -0.57575758, -0.51515152, -0.45454545, -0.39393939, -0.33333333,
#        -0.27272727, -0.21212121, -0.15151515, -0.09090909, -0.03030303,
#         0.03030303,  0.09090909,  0.15151515,  0.21212121,  0.27272727,
#         0.33333333,  0.39393939,  0.45454545,  0.51515152,  0.57575758,
#         0.63636364,  0.6969697 ,  0.75757576,  0.81818182,  0.87878788,
# ...

# %%
def perceptron(X,y):
    
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(1000):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
    return weights[0],weights[1:]
        
def step(z):
    return 1 if z>0 else 0

# %%
intercept,coef=perceptron(x,y)

# %%
print(coef)
print(intercept)
# Out:
# [1.0198596  0.33857969]
# 1.3000000000000003

# %%
m = -(coef[0]/coef[1])
b = -(intercept/coef[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x,y)
# Out:
# LogisticRegression()

# %%
lr.intercept_
# Out:
# array([3.13571596])

# %%
lr.coef_
# Out:
# array([[2.36679363, 0.02300492]])

# %%
m=-(lr.coef_[0][0]/lr.coef_[0][1])
b=-(lr.intercept_/lr.coef_[0][1])

# %%
x_input1=np.linspace(-3,3,100)
y_input1=m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,c='red')
plt.plot(x_input1,y_input1,c='yellow')

plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)

plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
def perceptro(x,y):
    x=np.insert(x,0,1,axis=1)
    weights=np.ones(x.shape[1])
    lr=.1
    
    for i in range(1000):
        j=np.random.randint(0,100)
        y_hat=sigmoid(np.dot(x[j],weights))
        weights=weights +  lr* (y[i]- y_hat)* x[j]
            
     
     
    return weights[0],weights[1:]

# %%
def sigmoid(z):
    return (1/(1+np.exp(-z)))

# %%
intercept,coef=perceptron(x,y)

# %%
print(intercept)
print(coef)
# Out:
# 1.3000000000000003
# [1.05343617 0.2221512 ]

# %%
m=-(coef[0]/coef[1])
b=-(intercept/coef[1])

# %%
x_input2=np.linspace(-3,3,100)
y_input2=m * x_input + b

# %%
plt.figure(figsize=(15,8))
plt.plot(x_input2,y_input2,c='green')
plt.plot(x_input,y_input,c='red')
plt.plot(x_input1,y_input1,c='yellow')

plt.scatter(x[:,0],x[:,1],c=y,cmap='winter')

plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
