# %%
import pandas as pd 
import numpy as np

# %%
# open a local csv  csv file

# %%
df=pd.read_csv('C:/Users/vaibh/Downloads/placement.csv')
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
# open a csv a file from url 
import requests
from io import StringIO
url = "https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv"

headers=  {"User-Agent": "Mozilla/5.0 (Macintosh;Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}

req = requests.get(url, headers=headers)

data = StringIO(req.text)

pd.read_csv(data)
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
# working with tsv file
# 4.sep parameter

# %%
df=pd.read_csv('C:/Users/vaibh/Downloads/profile_data_1.tsv')
df
# Out:
#     aa\tbb\tcccc\td\te\tff\tgg\thh\tii\tjjj\tk\tl\tMM\tNnN\tO\tpp\tqqq\trRr\tss\ttt
# 0    2.78189953831\t2.20468660914\t-0.0203163\t1.73...
# 1    1.18453523987\t7.68000061383\t0.00547178\t1.51...
# 2    0.616616233163\t6.41330587315\t-0.0303505\t1.5...
# 3    2.61246448327\t2.80480597932\t0.0187935\t1.680...
# 4    -3.96045301085\t6.52883111884\t0.0328429\t1.53...
# ..                                                 ...
# 494  -1.25078748126\t-1.95761048607\t0.0335502\t1.5...
# 495  -2.12811658791\t6.91895715169\t0.0175865\t1.74...
# 496  3.68104552819\t8.22765148017\t-0.0406756\t1.61...
# 497  4.40246360828\t9.08879454413\t0.0404229\t1.653...
# 498  0.168009534284\t5.31404067094\t-0.0190704\t1.6...
#
# [499 rows x 1 columns]

# %%
df=pd.read_csv('C:/Users/vaibh/Downloads/profile_data_1.tsv',sep=('\t'))
df
# Out:
#            aa        bb      cccc        d      e    ff          gg        hh  \
# 0    2.781900  2.204687 -0.020316  1.73618  88.40 -35.3 -346.523211  0.980845
# 1    1.184535  7.680001  0.005472  1.51820  69.10 -72.2 -661.273397 -0.009221
# 2    0.616616  6.413306 -0.030350  1.56272  62.00 -59.3 -832.420356  1.903280
# 3    2.612464  2.804806  0.018794  1.68033  33.40 -84.5 -520.417934 -0.278813
# 4   -3.960453  6.528831  0.032843  1.53609   2.38 -79.7 -677.989837  2.610669
# ..        ...       ...       ...      ...    ...   ...         ...       ...
# 494 -1.250787 -1.957610  0.033550  1.50371   1.90 -99.0 -232.386167  2.442141
# 495 -2.128117  6.918957  0.017587  1.74998  58.20 -85.1  413.875121  0.898852
# 496  3.681046  8.227651 -0.040676  1.61427   3.22 -81.9 -152.596876 -1.354549
# 497  4.402464  9.088795  0.040423  1.65371  63.80 -10.8 -385.846323 -0.184783
# 498  0.168010  5.314041 -0.019070  1.69143  73.20 -23.7   93.999242 -0.276504
#
# ...

# %%
# 5.index_col parameter : is used for the columns data convert into a index form

# %%
df=pd.read_csv('C:/Users/vaibh/Downloads/placement.csv',index_col=0)
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
# from server

# %%
import requests
from io import StringIO
url = "https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv"

headers=  {"User-Agent": "Mozilla/5.0 (Macintosh;Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}

req = requests.get(url, headers=headers)

data = StringIO(req.text)

pd.read_csv(data)
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
import requests
from io import StringIO
url = "https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv"

headers=  {"User-Agent": "Mozilla/5.0 (Macintosh;Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}

req = requests.get(url, headers=headers)

data = StringIO(req.text)

pd.read_csv(data,index_col='id')
# Out:
#     location_id                   address_1  address_2                 city  \
# id
# 1             1       2600 Middlefield Road        NaN         Redwood City
# 2             2            24 Second Avenue        NaN            San Mateo
# 3             3            24 Second Avenue        NaN            San Mateo
# 4             4            24 Second Avenue        NaN            San Mateo
# 5             5            24 Second Avenue        NaN            San Mateo
# 6             6           800 Middle Avenue        NaN           Menlo Park
# 7             7              500 Arbor Road        NaN           Menlo Park
# 8             8           800 Middle Avenue        NaN           Menlo Park
# 9             9       2510 Middlefield Road        NaN         Redwood City
# 10           10       1044 Middlefield Road        NaN         Redwood City
# 11           11         2140 Euclid Avenue.        NaN         Redwood City
# ...

# %%
# header parameter is used when the columns name is slide down into the row 

# now we have not any data set for practical use

# but syntax is 
pd.read_csv('C:/Users/vaibh/Downloads/test.csv', header=0)  

# when header=1 means your row is start with index 1

# %%
pd.read_csv('C:/Users/vaibh/Downloads/test.csv', header=0)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
# Usecols parameter: 
# is used for to choose  the specfic column

# %%
pd.read_csv('C:/Users/vaibh/Downloads/test.csv', usecols=['Name','Sex','Age'])
# Out:
#                                              Name     Sex   Age
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5
# 416                           Ware, Mr. Frederick    male   NaN
# 417                      Peter, Master. Michael J    male   NaN
#
# [418 rows x 3 columns]

# %%
# squeeze paramter : means choose a one columns in the data frame

# %%
pd.read_csv('C:/Users/vaibh/Downloads/test.csv',usecols=['Name'],squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 pd.read_csv('C:/Users/vaibh/Downloads/test.csv',usecols=['Name'],Squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'Squeeze'

# %%
# skiprows/nrows parameter /

# %%
pd.read_csv('C:/Users/vaibh/Downloads/test.csv')
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
pd.read_csv('C:/Users/vaibh/Downloads/test.csv',skiprows=[0,1,2,3])
# Out:
#       895  3                              Wirz, Mr. Albert    male    27  0  \
# 0     896  3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0  1
# 1     897  3                    Svensson, Mr. Johan Cervin    male  14.0  0
# 2     898  3                          Connolly, Miss. Kate  female  30.0  0
# 3     899  2                  Caldwell, Mr. Albert Francis    male  26.0  1
# 4     900  3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0  0
# ..    ... ..                                           ...     ...   ... ..
# 409  1305  3                            Spector, Mr. Woolf    male   NaN  0
# 410  1306  1                  Oliva y Ocana, Dona. Fermina  female  39.0  0
# 411  1307  3                  Saether, Mr. Simon Sivertsen    male  38.5  0
# 412  1308  3                           Ware, Mr. Frederick    male   NaN  0
# 413  1309  3                      Peter, Master. Michael J    male   NaN  1
#
#      0.1              315154    8.6625 Unnamed: 9  S
# ...

# %%
pd.read_csv('C:/Users/vaibh/Downloads/test.csv',nrows=100)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..          ...     ...                                                ...
# 95          987       3                         Tenglin, Mr. Gunnar Isidor
# 96          988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 97          989       3                          Makinen, Mr. Kalle Edvard
# 98          990       3                       Braf, Miss. Elin Ester Maria
# 99          991       3                       Nancarrow, Mr. William Henry
#
# ...

# %%
# encoding parameter : utf 8

# %%
pd.read_csv('C:/Users/vaibh/Downloads/zomato.csv',encoding='latin-1')
# Out:
#       Restaurant ID         Restaurant Name                          Cuisines  \
# 0           6317637        Le Petit Souffle        French, Japanese, Desserts
# 1           6304287        Izakaya Kikufuji                          Japanese
# 2           6300002  Heat - Edsa Shangri-La  Seafood, Asian, Filipino, Indian
# 3           6318506                    Ooma                   Japanese, Sushi
# 4           6314302             Sambo Kojin                  Japanese, Korean
# ...             ...                     ...                               ...
# 2193       18420467           HotMess Bakes                 Bakery, Fast Food
# 2194       18332869   London Street Kitchen    North Indian, Mughlai, Chinese
# 2195       18241878          Bablu Chic-Inn             Mughlai, North Indian
# 2196         312959             Babu Jhatka                      North Indian
# 2197            978               Bal Gopal             North Indian, Mughlai
#
# ...

# %%
# converters : convert any column value into a specific value  if u can change 

def rename(name):
    if name=='Excellent':
        return '*'
    else : 
        return name

# %%
pd.read_csv('C:/Users/vaibh/Downloads/zomato.csv',encoding='latin-1',converters={'Rating text':rename})
# Out:
#       Restaurant ID         Restaurant Name                          Cuisines  \
# 0           6317637        Le Petit Souffle        French, Japanese, Desserts
# 1           6304287        Izakaya Kikufuji                          Japanese
# 2           6300002  Heat - Edsa Shangri-La  Seafood, Asian, Filipino, Indian
# 3           6318506                    Ooma                   Japanese, Sushi
# 4           6314302             Sambo Kojin                  Japanese, Korean
# ...             ...                     ...                               ...
# 2193       18420467           HotMess Bakes                 Bakery, Fast Food
# 2194       18332869   London Street Kitchen    North Indian, Mughlai, Chinese
# 2195       18241878          Bablu Chic-Inn             Mughlai, North Indian
# 2196         312959             Babu Jhatka                      North Indian
# 2197            978               Bal Gopal             North Indian, Mughlai
#
# ...

# %%
# na_values : is used for remove the hifen(-) or cooma seperated values or placed holder ine the column values by nan

# %%
pd.read_csv('C:/Users/vaibh/Downloads/zomato.csv',na_values=['No'])
# Out:
#       Restaurant ID         Restaurant Name                          Cuisines  \
# 0           6317637        Le Petit Souffle        French, Japanese, Desserts
# 1           6304287        Izakaya Kikufuji                          Japanese
# 2           6300002  Heat - Edsa Shangri-La  Seafood, Asian, Filipino, Indian
# 3           6318506                    Ooma                   Japanese, Sushi
# 4           6314302             Sambo Kojin                  Japanese, Korean
# ...             ...                     ...                               ...
# 2193       18420467           HotMess Bakes                 Bakery, Fast Food
# 2194       18332869   London Street Kitchen    North Indian, Mughlai, Chinese
# 2195       18241878          Bablu Chic-Inn             Mughlai, North Indian
# 2196         312959             Babu Jhatka                      North Indian
# 2197            978               Bal Gopal             North Indian, Mughlai
#
# ...

# %%
# loading a huge data in chunks

# %%
pd.read_csv('C:/Users/vaibh/Downloads/zomato.csv',encoding='latin-1')
# Out:
#       Restaurant ID         Restaurant Name                          Cuisines  \
# 0           6317637        Le Petit Souffle        French, Japanese, Desserts
# 1           6304287        Izakaya Kikufuji                          Japanese
# 2           6300002  Heat - Edsa Shangri-La  Seafood, Asian, Filipino, Indian
# 3           6318506                    Ooma                   Japanese, Sushi
# 4           6314302             Sambo Kojin                  Japanese, Korean
# ...             ...                     ...                               ...
# 2193       18420467           HotMess Bakes                 Bakery, Fast Food
# 2194       18332869   London Street Kitchen    North Indian, Mughlai, Chinese
# 2195       18241878          Bablu Chic-Inn             Mughlai, North Indian
# 2196         312959             Babu Jhatka                      North Indian
# 2197            978               Bal Gopal             North Indian, Mughlai
#
# ...

# %%
df=pd.read_csv('C:/Users/vaibh/Downloads/zomato.csv',encoding='latin-1',chunksize=500)
df

# %%
for chunk in df:
    print(chunk.shape)
# Out:
# (500, 14)
# (500, 14)
# (500, 14)
# (500, 14)
# (198, 14)
